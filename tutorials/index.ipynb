# %% [markdown]
# # Working with index

# %% [markdown]
# ## Content
# * [Index types](#Index-types)
# * [How to create an index](#How-to-create-an-index)
#     * [from SEGY files](#from-SEGY-files)
#     * [from SPS files](#from-SPS-files)
# * [Conversion between types](#Conversion-between-types)
# * [Merge](#Merge)

# %% [markdown]
# ## Index types

# %% [markdown]
# There are 4 basic types of indices:
# * ```FieldIndex``` enumerates field records
# * ```SegyFilesIndex``` enumerates SEGY files
# * ```TraceIndex``` enumerates traces
# * ```BinsIndex``` enumerated bins of regular grid
#
# and ```CustomIndex``` that enables enumeration on a basis of any ```segyio.TraceField``` attribute, e.g. ```INLINE_3D``` or ```ShotPoint```.
#
# Each index contains basic SEGY trace headers: ```FieldRecord```, ```TraceNumber``` and ```TRACE_SEQUENCE_FILE```. Addinional headers depend on index type and on requisted extra headers.
#
# There is an easy convertion between index types. Let ```index``` be an instance of some intex type, then  ```FieldIndex(index)``` will be an instance of type ```FieldIndex```, while ```TraceIndex(index)``` will be an instance of type ```TraceIndex``` etc.
#
# Index can be created from a single SEGY file, from multiple SEGY files, from SPS files. Several indices can be merged together. Below we illustrate these options.

# %% [markdown]
# ## How to create an index

# %% [markdown]
# ### from SEGY files

# %% [markdown]
# ```FieldIndex```, ```TraceIndex```, ```SegyFilesIndex``` allow enumeration of traces, correspondong field records and additional metadata contained in set of SEGY files. For example, let's create an index of traces recorded a single segy file and include additional ```offset``` header:

# %%
import sys
import pandas as pd
import numpy as np

sys.path.append('..')
from geolog.src import FieldIndex, TraceIndex, SegyFilesIndex, BinsIndex, CustomIndex, SeismicBatch
from geolog.batchflow import Dataset

path_raw = '/notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy'

index_raw = TraceIndex(name='raw', extra_headers=['offset'], path=path_raw)

# %% [markdown]
# ```head()``` attribute (similar to pandas) shows 5 first traces:

# %%
index_raw.head()
# Out:
#   TraceNumber offset FieldRecord TRACE_SEQUENCE_FILE  \
#                                                  raw
# 0        1656     35      111906                   1
# 1        1657     36      111906                   2
# 2        1655     78      111906                   3
# 3        1658     79      111906                   4
# 4        1654    127      111906                   5
#
#                                              file_id
#                                                  raw
# 0  /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 1  /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 2  /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 3  /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 4  /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy

# %% [markdown]
# In the next example we will create an index of traces from all SEGY files in a directory. Note that SEGY files may contain auxiliary traces, they can be dropped by ```drop_duplicates``` method:

# %%
path_segy = '/notebooks/egor/2D_Valyton/prof_37/segy/*.sgy'

index_segy = (FieldIndex(name='raw', path=path_segy)
              .drop_duplicates(subset=[('FieldRecord', ''), ('TraceNumber', '')], keep='last'))
index_segy.head()
# Out:
#             TraceNumber TRACE_SEQUENCE_FILE  \
#                                         raw
# FieldRecord
# 354                   1                   3
# 354                   2                   4
# 354                   3                   5
# 354                   4                   6
# 354                   5                   7
#
#                                                        file_id
#                                                            raw
# FieldRecord
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...

# %% [markdown]
# Besides ```FieldIndex```, ```TraceIndex``` and ```SegyFilesIndex``` that enumerate field records, traces or files, it is possible to create a custom index on a basis of any ```segyio.TraceField``` attribute, e.g. ```INLINE_3D```, ```ShotPoint```, ```CDP``` etc. For example, let's crate an index of shot points:

# %%
index_shot = CustomIndex(name='raw', index_name='ShotPoint', path=path_raw)

index_shot.head()
# Out:
#           FieldRecord TraceNumber TRACE_SEQUENCE_FILE  \
#                                                   raw
# ShotPoint
# 42000          111906        1656                   1
# 42000          111906        1657                   2
# 42000          111906        1655                   3
# 42000          111906        1658                   4
# 42000          111906        1654                   5
#
#                                                      file_id
#                                                          raw
# ShotPoint
# 42000      /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 42000      /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 42000      /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 42000      /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 42000      /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy

# %% [markdown]
# ### from SPS files

# %% [markdown]
# ```TraceIndex``` and ```FieldIndex``` can be alternatively constructed from SPS files. As a by-product, it will indlude offsets and a number of other metadata:

# %%
dfx = pd.read_csv('/notebooks/egor/2D_Valyton/sps/ALL_VALUNT0910_X37.csv')
dfr = pd.read_csv('/notebooks/egor/2D_Valyton/sps/ALL_VALUNT0910_R_utm.csv')
dfs = pd.read_csv('/notebooks/egor/2D_Valyton/sps/ALL_VALUNT0910_S_utm.csv')

index_sps = FieldIndex(dfx=dfx, dfr=dfr, dfs=dfs)
index_sps.head()
# Out:
#             sline   sid rline  rid TraceNumber point_index sht_depth uphole  \
#
# FieldRecord
# 481           S37  1011   R37  101           1           1      18.0    8.0
# 480           S37  1031   R37  101           1           1      18.0    8.0
# 479           S37  1051   R37  101           1           1      18.0    9.0
# 478           S37  1071   R37  101           1           1      18.0    9.0
# 477           S37  1091   R37  101           1           1      18.0    8.0
#
#                    x_s        y_s   z_s       x_r        y_r   z_r     offset
#
# FieldRecord
# 481          338283.90  7026994.0  70.0  338283.9  7026994.0  70.0   0.000000
# 480          338288.62  7027043.5  69.9  338283.9  7026994.0  70.0  24.862263
# 479          338293.30  7027093.5  69.8  338283.9  7026994.0  70.0  49.971517
# 478          338298.00  7027143.0  69.7  338283.9  7026994.0  70.0  74.832830
# 477          338302.70  7027193.0  69.6  338283.9  7026994.0  70.0  99.943034

# %% [markdown]
# To create a ```Binsindex``` one should specify ```bin_size```. During index construction an optimal grid position will be searched:

# %%
dfx = pd.read_csv('/notebooks/egor/Xfield/Xfield_X.csv')
dfr = pd.read_csv('/notebooks/egor/Xfield/Xfield_R.csv')
dfs = pd.read_csv('/notebooks/egor/Xfield/Xfield_S.csv')

bin_size = 1000

index_bin = BinsIndex(dfr=dfr, dfs=dfs, dfx=dfx, bin_size=(bin_size, bin_size), iters=10)
index_bin.head()
# Out:
#        FieldRecord  sline   sid  rline   rid TraceNumber       x_s        y_s  \
#
# bin_id
# 25/5       228691Z  S2105  5139  R5103  2049           1  493989.9  6608026.0
# 25/5       228671Z  S2105  5140  R5103  2049           1  493989.9  6608076.0
# 25/5       228651Z  S2105  5141  R5103  2049           1  493989.9  6608126.0
# 25/5       228631Z  S2105  5142  R5103  2049           1  493989.9  6608175.5
# 25/5       228611Z  S2105  5143  R5103  2049           1  493989.9  6608226.0
#
#          z_s       x_r        y_r   z_r     x_cdp       y_cdp        az  \
#
# bin_id
# 25/5    38.7  491215.7  6606201.5  41.4  492602.8  6607113.75 -2.559846
# 25/5    38.6  491215.7  6606201.5  41.4  492602.8  6607138.75 -2.547369
# 25/5    38.6  491215.7  6606201.5  41.4  492602.8  6607163.75 -2.535098
# 25/5    38.6  491215.7  6606201.5  41.4  492602.8  6607188.50 -2.523153
# 25/5    38.7  491215.7  6606201.5  41.4  492602.8  6607213.75 -2.511172
#
#              offset
#
# bin_id
# 25/5    1660.194709
# 25/5    1674.062117
# 25/5    1688.185852
# 25/5    1702.414582
# 25/5    1717.176890

# %% [markdown]
# The heatmap shows a distribution of traces within bins:

# %%
index_bin.show_heatmap()

# %% [markdown]
# ## Conversion between types

# %% [markdown]
# Indices can be easily converted to each other type. For example, ```FieldIndex``` to ```TraceIndex```:

# %%
SegyFilesIndex(index_segy, name='raw').head()
# Out:
#                                                    FieldRecord TraceNumber  \
#
# (file_id, raw)
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...         354           1
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...         354           2
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...         354           3
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...         354           4
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...         354           5
#
#                                                    TRACE_SEQUENCE_FILE
#                                                                    raw
# (file_id, raw)
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...                   3
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...                   4
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...                   5
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...                   6
# /notebooks/egor/2D_Valyton/prof_37/segy/0000035...                   7

# %% [markdown]
# or vise-versa:

# %%
FieldIndex(index_raw).head()
# Out:
#             TraceNumber offset TRACE_SEQUENCE_FILE  \
#                                                raw
# FieldRecord
# 111906             1656     35                   1
# 111906             1657     36                   2
# 111906             1655     78                   3
# 111906             1658     79                   4
# 111906             1654    127                   5
#
#                                                        file_id
#                                                            raw
# FieldRecord
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy

# %% [markdown]
# or ```BinsIndex``` to ```FieldIndex```:

# %%
FieldIndex(index_bin).head()
# Out:
#             bin_id  sline   sid  rline   rid TraceNumber       x_s        y_s  \
#
# FieldRecord
# 228691Z       25/5  S2105  5139  R5103  2049           1  493989.9  6608026.0
# 228671Z       25/5  S2105  5140  R5103  2049           1  493989.9  6608076.0
# 228651Z       25/5  S2105  5141  R5103  2049           1  493989.9  6608126.0
# 228631Z       25/5  S2105  5142  R5103  2049           1  493989.9  6608175.5
# 228611Z       25/5  S2105  5143  R5103  2049           1  493989.9  6608226.0
#
#               z_s       x_r        y_r   z_r     x_cdp       y_cdp        az  \
#
# FieldRecord
# 228691Z      38.7  491215.7  6606201.5  41.4  492602.8  6607113.75 -2.559846
# 228671Z      38.6  491215.7  6606201.5  41.4  492602.8  6607138.75 -2.547369
# 228651Z      38.6  491215.7  6606201.5  41.4  492602.8  6607163.75 -2.535098
# 228631Z      38.6  491215.7  6606201.5  41.4  492602.8  6607188.50 -2.523153
# 228611Z      38.7  491215.7  6606201.5  41.4  492602.8  6607213.75 -2.511172
#
#                   offset
#
# FieldRecord
# 228691Z      1660.194709
# 228671Z      1674.062117
# 228651Z      1688.185852
# 228631Z      1702.414582
# 228611Z      1717.176890

# %% [markdown]
# or custom shot index for ```FieldIndex```:

# %%
FieldIndex(index_shot).head()
# Out:
#             ShotPoint TraceNumber TRACE_SEQUENCE_FILE  \
#                                                   raw
# FieldRecord
# 111906          42000        1656                   1
# 111906          42000        1657                   2
# 111906          42000        1655                   3
# 111906          42000        1658                   4
# 111906          42000        1654                   5
#
#                                                        file_id
#                                                            raw
# FieldRecord
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy
# 111906       /notebooks/egor/noise_data/DN02A_LIFT_AMPSCAL.sgy

# %% [markdown]
# ## Merge

# %% [markdown]
# Two index instances can be merged on common headers. For example, ```index_segy``` does not contain offsets. However, we can merge it with ```index_sps``` that includes offsets:

# %%
index_segy = index_segy.merge(index_sps)
index_segy.head()
# Out:
#             TraceNumber TRACE_SEQUENCE_FILE  \
#                                         raw
# FieldRecord
# 354                   1                   3
# 354                   2                   4
# 354                   3                   5
# 354                   4                   6
# 354                   5                   7
#
#                                                        file_id sline   sid  \
#                                                            raw
# FieldRecord
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...   S37  3591
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...   S37  3591
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...   S37  3591
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...   S37  3591
# 354          /notebooks/egor/2D_Valyton/prof_37/segy/000003...   S37  3591
#
#             rline  rid point_index sht_depth uphole        x_s        y_s  \
#
# FieldRecord
# 354           R37  219           1      18.0   14.0  338886.78  7033413.0
# 354           R37  220           1      18.0   14.0  338886.78  7033413.0
# 354           R37  221           1      18.0   14.0  338886.78  7033413.0
# 354           R37  222           1      18.0   14.0  338886.78  7033413.0
# 354           R37  223           1      18.0   14.0  338886.78  7033413.0
#
#               z_s        x_r        y_r   z_r       offset
#
# FieldRecord
# 354          71.5  338560.00  7029929.5  76.0  1749.396855
# 354          71.5  338562.40  7029954.5  76.1  1736.839416
# 354          71.5  338564.70  7029979.5  76.2  1724.286648
# 354          71.5  338567.00  7030004.5  76.8  1711.733880
# 354          71.5  338569.38  7030029.0  77.4  1699.426283

# %% [markdown]
# Now we can load traces sorted by offset:

# %%
cv = 1

batch = (Dataset(index_segy, SeismicBatch).next_batch(50)
         .load(components='raw', sort_by='offset'))

batch.show_traces('raw', batch.indices[20], figsize=(10, 7),
                  vmin=-cv, vmax=cv, cmap='gray')

# %% [markdown]
# Enjoy!
