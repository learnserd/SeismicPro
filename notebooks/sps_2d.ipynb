# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfr = pd.read_csv('/home/egor/Desktop/2D_Valyton/sps/ALL_VALUNT0910_R_utm.txt', sep='\s+', header=None)
dfr.columns = ['rline', 'rid', 'x', 'y', 'z']
dfr.head()
# Out:
#   rline  rid          x           y     z
# 0    R1  101  343149.76  7048867.42  57.4
# 1    R1  102  343174.55  7048864.62  57.7
# 2    R1  103  343199.34  7048861.72  58.0
# 3    R1  104  343224.23  7048858.92  58.2
# 4    R1  105  343249.02  7048856.12  58.5

# %%
dfs = pd.read_csv('/home/egor/Desktop/2D_Valyton/sps/ALL_VALUNT0910_S_utm.txt', sep='\s+', header=None)
dfs.columns = ['sline', 'sid', 'point_index', 'sht_depth', 'uphole', 'x', 'y', 'z']
dfs = dfs.dropna(axis=0)
dfs.head()
# Out:
#   sline   sid  point_index  sht_depth  uphole          x           y     z
# 0    S1  1011          1.0       18.0    13.0  343149.76  7048867.42  57.4
# 1    S1  1031          1.0       18.0    14.0  343199.34  7048861.72  58.0
# 2    S1  1051          1.0       18.0    18.0  343249.02  7048856.12  58.5
# 3    S1  1071          1.0       18.0    15.0  343300.30  7048870.82  58.5
# 4    S1  1091          1.0       18.0    12.0  343352.48  7048889.01  58.1

# %%
# %matplotlib notebook
sline = 'S35'
rline = 'R9'
sid = 1011
rid = 151

plt.scatter(dfs['x'], dfs['y'], s=10, label="S")
plt.scatter(dfr['x'].values, dfr['y'].values, s=1, label="R")
for line in dfs['sline'].unique():
    p = dfs[(dfs['sline'] == line) & (dfs['sid'] == 1011)]
    plt.text(p['x'] - 2000, p['y'], line[1:])

plt.scatter(dfs[dfs['sline'] == sline]['x'], dfs[dfs['sline'] == sline]['y'], label="S_line", c='black', s=10)
plt.scatter(dfr[dfr['rline'] == rline]['x'], dfr[dfr['rline'] == rline]['y'], label="R_line", c='r', s=10)
plt.scatter(dfs[dfs['sid'] == sid]['x'], dfs[dfs['sid'] == sid]['y'], label="Sid", c='g')
plt.scatter(dfr[dfr['rid'] == rid]['x'], dfr[dfr['rid'] == rid]['y'], label="Rid", c='y', s=20)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8601633300708">

# %%
dfx = pd.read_csv('/home/egor/Desktop/2D_Valyton/sps/ALL_VALUNT0910_X.sps',
                  sep='\s+', header=None, skiprows=49)
dfx.columns = ['type_num', 'xid', 'sline', 'sid', 'from_channel', 'to_channel', 'rline',
               'from_receiver', 'to_receiver']
dfx['sline'] = dfx['sline'].apply(lambda x: "S" + str(x))
dfx['rline'] = dfx['rline'].apply(lambda x: "R" + str(x))
dfx.head()
# Out:
#   type_num   xid sline   sid  from_channel  to_channel rline  from_receiver  \
# 0       X1  4514    S1  1011             1         141    R1            101
# 1       X1  4513    S1  1031             1         143    R1            101
# 2       X1  4512    S1  1051             1         145    R1            101
# 3       X1  4511    S1  1071             1         147    R1            101
# 4       X1  4510    S1  1091             1         149    R1            101
#
#    to_receiver
# 0          241
# 1          243
# 2          245
# 3          247
# 4          249

# %%
segd = dfx[dfx['xid'] == 354]
segd
# Out:
#       type_num  xid sline   sid  from_channel  to_channel rline  \
# 14489      X35  354   S35  6771             1         281   R35
# 15814       X1  354   S37  3591             1         281   R37
#
#        from_receiver  to_receiver
# 14489            537          817
# 15814            219          499

# %%
# %matplotlib notebook
segd = dfx[dfx['xid'] == 460]

plt.scatter(dfs['x'], dfs['y'], s=10, label="S")
plt.scatter(dfr['x'].values, dfr['y'].values, s=1, label="R")
for line in dfs['sline'].unique():
    p = dfs[(dfs['sline'] == line) & (dfs['sid'] == 1011)]
    plt.text(p['x'] - 2000, p['y'], line[1:])

for index, row in segd.iterrows():
    view = dfr[(dfr['rline'] == row['rline']) &
               (dfr['rid'] >= row['from_receiver']) &
               (dfr['rid'] <= row['to_receiver'])]
    plt.scatter(view['x'], view['y'], label="Receivers", c='black', s=10)

    view = dfs[(dfs['sline'] == row['sline']) & (dfs['sid'] == row['sid'])]
    plt.scatter(view['x'], view['y'], label="Shot", c='r', s=20)

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8601633300708">
